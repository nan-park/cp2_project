# %% [markdown]
# <a href="https://colab.research.google.com/github/nan-park/cp2_project/blob/main/sbert_module_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# import os
# os.get_cwd()

# %%
# !pip install scikit-multilearn
# !pip install sentence-transformers
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 KB 8.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.3 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=b366823bac749ab6b537ed8d771134ff605680105cf18cd3a8778030cca5695d
# ...

# %%
MODULE_PATH = "/content/gdrive/MyDrive/cp2/sbert_module"

# !python {MODULE_PATH}/trainer.py
# Out:
# [INFO] (2023.02.10-08:03:53) Load SBERT Model...
# [INFO] (2023.02.10-08:03:56) Done! (2.919s)
# [INFO] (2023.02.10-08:03:56) Vectorize text data...
# [INFO] (2023.02.10-08:04:06) Done! (9.763s)
# [INFO] (2023.02.10-08:04:06) Model Training...
# Epoch 1/50
# 58/58 [==============================] - 2s 15ms/step - loss: 26.5133 - F1_score: 0.5894 - PRAUC: 0.4098 - val_loss: 20.5192 - val_F1_score: 0.6210 - val_PRAUC: 0.5986
# Epoch 2/50
# 58/58 [==============================] - 0s 8ms/step - loss: 18.1789 - F1_score: 0.7686 - PRAUC: 0.8109 - val_loss: 13.8178 - val_F1_score: 0.6284 - val_PRAUC: 0.6262
# Epoch 3/50
# 58/58 [==============================] - 0s 8ms/step - loss: 12.0875 - F1_score: 0.7689 - PRAUC: 0.8428 - val_loss: 8.7104 - val_F1_score: 0.6401 - val_PRAUC: 0.6346
# Epoch 4/50
# 58/58 [==============================] - 0s 8ms/step - loss: 7.8409 - F1_score: 0.7706 - PRAUC: 0.8415 - val_loss: 5.3825 - val_F1_score: 0.6219 - val_PRAUC: 0.6305
# Epoch 5/50
# ...

# %%
# !python {MODULE_PATH}/sbert_trainer.py
# Out:
# Epoch:   0% 0/1 [00:00<?, ?it/s]
# Iteration:   0% 0/868 [00:00<?, ?it/s]
# Iteration:   0% 1/868 [00:01<16:10,  1.12s/it]
# Iteration:   0% 2/868 [00:01<11:13,  1.29it/s]
# Iteration:   0% 3/868 [00:02<11:32,  1.25it/s]
# Iteration:   0% 4/868 [00:02<10:09,  1.42it/s]
# Iteration:   1% 5/868 [00:03<09:42,  1.48it/s]
# Iteration:   1% 6/868 [00:04<09:34,  1.50it/s]
# Iteration:   1% 7/868 [00:04<09:57,  1.44it/s]
# Iteration:   1% 8/868 [00:05<09:19,  1.54it/s]
# Iteration:   1% 9/868 [00:06<09:30,  1.50it/s]
# Iteration:   1% 10/868 [00:06<09:47,  1.46it/s]
# Iteration:   1% 11/868 [00:07<09:36,  1.49it/s]
# Iteration:   1% 12/868 [00:08<09:27,  1.51it/s]
# Iteration:   1% 13/868 [00:08<09:09,  1.55it/s]
# Iteration:   2% 14/868 [00:09<09:00,  1.58it/s]
# Iteration:   2% 15/868 [00:09<08:49,  1.61it/s]
# Iteration:   2% 16/868 [00:10<08:45,  1.62it/s]
# Iteration:   2% 17/868 [00:10<08:41,  1.63it/s]
# Iteration:   2% 18/868 [00:11<08:48,  1.61it/s]
# ...
